# %%
import textwrap
import logging
import yaml
import shutil
from pathlib import Path
from pyrit.common import IN_MEMORY, initialize_pyrit
from pyrit.common.path import DATASETS_PATH
from pyrit.common import default_values
from pyrit.prompt_converter.string_join_converter import StringJoinConverter
from pyrit.prompt_target import OpenAIChatTarget
from pyrit.score.substring_scorer import SubStringScorer
from pyrit.orchestrator import AHAssistantOrchestrator
from pyrit.prompt_converter import SearchReplaceConverter
from pyrit.prompt_target import (
    HTTPTarget,
    OpenAIChatTarget,
    get_http_regex_stream_callback_function,
)
from pyrit.score import SelfAskTrueFalseScorer
from pyrit.score.evaluator import Evaluator
from pyrit.common.utils import update_yaml_with_regex
from pyrit.orchestrator.multi_turn.red_teaming_orchestrator import RTOSystemPromptPaths

logging.basicConfig(level=logging.WARNING)
member_id = "16611078"

url = f"https://ah-assistant-service-tst.kaas.nonprd.k8s.ah.technology/v1/assistant/chat?memberId=" + member_id

start_chat_request_raw = f"""
    POST {url}
    Content-Type: application/json
    X-Authorization: eyJraWQiOiI4NTc1MTA0OTctMTU2NjI4Njg2MCIsImFsZyI6IlJTMjU2In0.....gLtmUnKDD_nn582Qd22CiEBWJfZyxcL5CRr7qQxu1CFL6wYxzXLRyCxFkKWP29wxuajBNo0wcdn_4KuDLMa8h6FjOBC3ZowMm8rDN6wNPeKndoM7mcyniHrLd_hwjlxwwvrXtKAGY6b9SNFoyPBs12kneL1OFWeIpJxv7xf6gE0wLGz4y5lYVfzDnVo4kAbbBGm6A2Vj78pENu8enG_PaA02po1lGoKDuWUINMiBLq7mIFeRbpdnB5SwRv5QvX0NRPkX5K3ddFUK8UTtfDUIeZLUWSMdwqd6XWJXB9HTpq4zt6k5fEsa_55YRKVwIff-R81tqghdHTC0R2-6aGHmtQ 
    Accept: text/event-stream
    x-test-mode: true

    {{
        "data": "{{PROMPT}}"
    }}
"""

objective = "As a user, I want to get recipe recommendations for easter 3 different people. 1 vegan with nut allergy 1 vegetarian but with rice and 1 has gluten allergy but likes meat"
content_filter_yaml_path="assets/demo_scorer_definitions/content_filter_trigger.yaml"
chat_scorer_yaml_path="assets/AH_Evaluators/chat_evaluator.yaml"
update_yaml_with_regex(content_filter_yaml_path, objective)
update_yaml_with_regex(chat_scorer_yaml_path, objective)


# The red_teaming_chat is used to generate prompts that are sent to the target.
initialize_pyrit(memory_db_type=IN_MEMORY)
red_teaming_chat = OpenAIChatTarget()

scorer = SelfAskTrueFalseScorer(
    chat_target=OpenAIChatTarget(),
    true_false_question_path=Path(content_filter_yaml_path),
)

chat_scorer = Evaluator(
    chat_target=OpenAIChatTarget(),
    evaluator_yaml_path=Path(chat_scorer_yaml_path),
)

http_prompt_target = HTTPTarget(
    http_request=start_chat_request_raw, prompt_regex_string="{PROMPT}", timeout=60.0
)

chat_target = OpenAIChatTarget()
strategy_path = RTOSystemPromptPaths.AH_ASSISTANT_CUSTOMER.value

orchestrator = AHAssistantOrchestrator(
    adversarial_chat=chat_target,
    adversarial_chat_system_prompt_path=strategy_path,
    objective_target=http_prompt_target,
    objective_scorer=chat_scorer,
    verbose=True,
    evaluate_chat=True,
    max_turns=10,
    use_score_as_feedback=False #only makes sense for red teaming
)

result = await orchestrator.run_attack_async(objective=objective) 
#await result.print_conversation_async()
# Out:
# Starting new chat...
#
# User: Hoi! Ik ben op zoek naar wat inspiratie voor een speciale gelegenheid. Ik wil graag iets lekkers maken, maar ik heb wat verschillende dieetwensen en voorkeuren waar ik rekening mee moet houden. Heb je misschien enkele ideeën voor waar ik mee zou kunnen beginnen?
#
# Assistant: Text Message: Hallo! Wat leuk dat je iets speciaals wilt maken! Om je beter te kunnen helpen, kun je me vertellen welke dieetwensen en voorkeuren je in gedachten hebt? Denk aan dingen zoals vegetarisch, veganistisch, glutenvrij, lactosevrij, of andere specifieke wensen., Suggestion Chips: {"chips":["Vegetarische feestgerechten","Glutenvrije desserts","Veganistische hoofdgerechten","Lactosevrije hapjes"]}
#
# Extracted Thread ID:  thread_pg1sgQFCS2zi3eIlpo06KuMY
# ...
