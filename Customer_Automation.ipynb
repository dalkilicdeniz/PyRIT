# %%
import textwrap
import logging
import yaml
import shutil
from pathlib import Path
from pyrit.common import IN_MEMORY, initialize_pyrit
from pyrit.common.path import DATASETS_PATH
from pyrit.common import default_values
from pyrit.prompt_converter.string_join_converter import StringJoinConverter
from pyrit.prompt_target import OpenAIChatTarget
from pyrit.score.substring_scorer import SubStringScorer
from pyrit.orchestrator import AHAssistantOrchestrator
from pyrit.prompt_converter import SearchReplaceConverter
from pyrit.prompt_target import (
    HTTPTarget,
    OpenAIChatTarget,
    get_http_regex_stream_callback_function,
)
from pyrit.score.evaluator import Evaluator
from pyrit.common.utils import update_yaml_with_regex
from pyrit.orchestrator.multi_turn.red_teaming_orchestrator import RTOSystemPromptPaths

logging.basicConfig(level=logging.WARNING)
member_id = "16611078"

url = f"https://ah-assistant-service-tst.kaas.nonprd.k8s.ah.technology/v1/assistant/chat?memberId=" + member_id

start_chat_request_raw = f"""
    POST {url}
    Content-Type: application/json
    X-Authorization: eyJraWQiOiI3MTIwMzI0ODktMjA3MDQwNzEwNCIsImFsZyI6IlJTMjU2In0.....Kwst6AjzCHtkmmt6kY7VRh010J52R948TS5xWTd6MzddIoH2yG4NEUWkxtNfmbDe3ZR6VbmSIOUcTI7anAgsvQ6QZEldyHCIMntJgq7c05kD1bEKGz9y33FCpX1DHOS2bMwpOb_j3XLhBE7iR_ehcHXs-D8fdHAficrIn9T5OFxsGIP11ouA9ofCEybWwlivL8uOeDOOiRsII6pFKaxiRP4nQwCBnPQBd8FPrWrqdkuLanCQbm8cxW2C5XDSMeAJogPL3yldK4j2K6IBRXdiinNTTU1HskCeuRS5nn_D7VhdcYThZsG7OmWM5QKWwaetNgxuqMxUEiIiRpZP9CVsFA 
    Accept: text/event-stream
    x-test-mode: true

    {{
        "data": "{{PROMPT}}"
    }}
"""

objective = "As a user, I want to learn step for step cooking for vega beef wellington"
evaluator_prompt_variables = {"objective" : objective}

content_classifier_yaml_path="assets/demo_scorer_definitions/ah_content_classifier.yaml"
chat_scorer_yaml_path="assets/AH_Evaluators/chat_evaluator.yaml"

# The red_teaming_chat is used to generate prompts that are sent to the target.
initialize_pyrit(memory_db_type=IN_MEMORY)
red_teaming_chat = OpenAIChatTarget()

# This is used to score single responses
scorer = Evaluator(
    chat_target=OpenAIChatTarget(),
    evaluator_yaml_path=Path(content_classifier_yaml_path),
    additional_evaluator_variables=evaluator_prompt_variables
)

#This is used to score the whole chat
chat_scorer = Evaluator(
    chat_target=OpenAIChatTarget(),
    evaluator_yaml_path=Path(chat_scorer_yaml_path),
    additional_evaluator_variables=evaluator_prompt_variables,
    scorer_type="float_scale"
)

http_prompt_target = HTTPTarget(
    http_request=start_chat_request_raw, prompt_regex_string="{PROMPT}", timeout=60.0
)

chat_target = OpenAIChatTarget()
strategy_path = RTOSystemPromptPaths.AH_ASSISTANT_CUSTOMER.value

orchestrator = AHAssistantOrchestrator(
    adversarial_chat=chat_target,
    adversarial_chat_system_prompt_path=strategy_path,
    objective_target=http_prompt_target,
    objective_scorer=chat_scorer,
    verbose=True,
    evaluate_chat=True,
    max_turns=10,
    use_score_as_feedback=True 
)

result = await orchestrator.run_attack_async(objective=objective) 
#await result.print_conversation_async()
# Out:
# Starting new chat...
#
# User: Ik ben dol op koken, maar ben op zoek naar iets nieuws om te maken. Heb je suggesties voor iets interessants?
#
# Assistant: Text Message: Hallo! Wat leuk dat je dol op koken bent! Hier zijn een paar suggesties voor interessante gerechten die je kunt proberen:- Een exotische curry met groenten en kikkererwten.- Zelfgemaakte sushi met verse ingrediënten.- Een creatieve quiche met seizoensgebonden groenten.- Een verrassende salade met fruit en noten.Laat me weten als je meer details wilt over een van deze gerechten!, Suggestion Chips: {"chips":["Exotische curry recepten","Zelf sushi maken","Quiche met seizoensgroenten","Salade met fruit en noten"]}
#
# Extracted Thread ID:  thread_bLiZKrojUUzrTNqKGHFSYoZA
# ...
