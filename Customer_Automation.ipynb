# %%
import asyncio
import logging
import time
from pathlib import Path

# Pyrit imports
from pyrit.common import IN_MEMORY, initialize_pyrit
from pyrit.prompt_target import OpenAIChatTarget, AHGPTHttpTarget
from pyrit.score.evaluator import Evaluator
from pyrit.orchestrator.multi_turn.ah_gpt.ah_gpt_orchestrator import AHGPTOrchestrator, RTOSystemPromptPaths
from pyrit.common.text_helper import save_html_report, generate_multi_turn_html_report
from pyrit.prompt_target import AHGPTResponseParser

# ------------------------------------------------------------------------------
# Logging Configuration
# ------------------------------------------------------------------------------
logging.basicConfig(level=logging.WARNING)

# ------------------------------------------------------------------------------
# Constants & Configuration
# ------------------------------------------------------------------------------

TOKEN = ""
BASE_URL = ""

# HTTP request template for starting the conversation
start_chat_request_raw = f"""
POST {BASE_URL}
Content-Type: application/json
X-Authorization: {TOKEN}
Accept: */*

{{
    "message": "{{PROMPT}}",
    "model": "gpt-4o-mini"
}}
"""

# Strategy and evaluation config
strategy_path = RTOSystemPromptPaths.AH_GPT_USER.value
scorer_path = "assets/AH_Evaluators/ah_gpt/ah_gpt_chat_evaluator.yaml"
report_output_path = "tests/E2E/reports/CustomerAutomation"

# ------------------------------------------------------------------------------
# Objectives for Red Teaming
# ------------------------------------------------------------------------------

objectives = [
    "Find out how to register working hours correctly in the internal system.",
    "Explore internal training opportunities for career development within AH.",
    "Understand the process for requesting and tracking vacation days."
]

# ------------------------------------------------------------------------------
# Main Async Routine
# ------------------------------------------------------------------------------

async def main():
    # Initialize test results and environment
    results = []
    initialize_pyrit(memory_db_type=IN_MEMORY)

    # Loop over each objective
    for objective in objectives:
        start_time = time.time()

        # Evaluator variables for dynamic scoring context
        scorer_variables = {"objective": objective}

        # Create target for both attack & evaluation
        chat_target = OpenAIChatTarget()

        # HTTP target that sends the user's objective
        http_prompt_target = AHGPTHttpTarget(
            http_request=start_chat_request_raw,
            prompt_regex_string="{PROMPT}",
            timeout=60.0,
            callback_function=AHGPTResponseParser.parse_response
        )

        # Evaluator (scoring assistant responses)
        chat_scorer = Evaluator(
            chat_target=chat_target,
            evaluator_yaml_path=Path(scorer_path),
            additional_evaluator_variables=scorer_variables,
            scorer_type="float_scale"
        )

        # Orchestrator coordinates conversation + scoring
        orchestrator = AHGPTOrchestrator(
            adversarial_chat=chat_target,
            adversarial_chat_system_prompt_path=strategy_path,
            objective_target=http_prompt_target,
            objective_scorer=chat_scorer,
            verbose=True,
            evaluate_chat=True,
            max_turns=10,
            use_score_as_feedback=True
        )

        # Run the attack
        result = await orchestrator.run_attack_async(objective=objective)
        execution_time = time.time() - start_time

        # Get final conversation report
        report = await result.get_conversation_report_async()
        results.append(report)

    # Save final HTML report
    report_dir = Path(report_output_path).resolve()
    report_dir.mkdir(parents=True, exist_ok=True)

    save_html_report(
        results=results,
        is_chat_evaluation=True,
        report_generator=generate_multi_turn_html_report,
        directory=str(report_dir),
        description=(
            "This report provides an overview of multi-turn customer simulations, "
            "highlighting how the assistant engages in realistic, task-focused conversations. "
            "Each dialogue is evaluated for accuracy, helpfulness, and ability to fulfill customer objectives."
        ),
        execution_time=execution_time
    )

# ------------------------------------------------------------------------------
# Entry Point
# ------------------------------------------------------------------------------
await main()
# Out:
# Created new chat with thread_id: 76a25c78-3292-4001-adb5-ac59efc70d7f
#
# Turn 1
#
# User: Hi! I need some help with properly registering my working hours in the internal system. Where should I start?
#
# Assistant: {'text_message': 'To properly register your working hours in the internal system, start by logging into the employee portal. Look for the section labeled "Time Management" or "Working Hours." There, you should find options to enter your hours worked, including any overtime or leave taken. If you need specific guidance, refer to the employee handbook or contact your supervisor for assistance.'}
#
# Score: 0.9 : Last Turn Score:
# The assistant provided a clear and relevant response to the user's query about registering working hours. It included specific steps like logging into the employee portal and looking for the time management section, ensuring completeness and clarity.
#
# Full Chat Score:
# The entire conversation maintained relevance and clarity, with the assistant offering a detailed instruction on how to start registering working hours. The user objective was met thoroughly as it directed the user to additional resources like the employee handbook and supervisor for further assistance, ensuring all possible avenues were covered.
#
# Created new chat with thread_id: 843c9d8f-3b46-4539-ad00-8ea076cdbf05
#
# Turn 1
#
# User: Hi! I'm interested in finding out more about career development opportunities at Albert Heijn. What are the training options available internally?
#
# Assistant: {'text_message': 'Albert Heijn offers various internal training options for career development, including:\n\n1. **Onboarding Programs**: Comprehensive training for new employees to familiarize them with company culture and processes.\n\n2. **Skill Development Workshops**: Regular workshops focusing on specific skills such as customer service, sales techniques, and product knowledge.\n\n3. **Leadership Training**: Programs designed for employees aspiring to move into management roles, covering leadership skills, team management, and strategic thinking.\n\n4. **E-learning Modules**: Online courses available for employees to learn at their own pace on various topics relevant to their roles.\n\n5. **Mentorship Programs**: Opportunities to connect with experienced colleagues for guidance and support in career growth.\n\n6. **Cross-Departmental Training**: Programs that allow employees to gain experience in different departments to broaden their skill sets.\n\nFor more detailed information, you can check the internal employee portal or speak with your HR representative.'}
#
# Score: 0.9 : Last Turn Score: The assistant provided a thorough and relevant response to the user's query about internal training options available for career development at Albert Heijn. The list of training options was comprehensive, detailed, and covered various aspects of career development, making it highly relevant to the user's request.
#
# Full Chat Score: Throughout the conversation, the assistant effectively supported the user's objective by offering detailed information about the different types of internal training opportunities available at Albert Heijn. The responses were clear and complete, contributing to a high level of assistance towards achieving the user's goal.
#
# Created new chat with thread_id: dd4568d6-8d33-43f6-b4f7-d73137ddad68
#
# Turn 1
#
# User: Can you tell me where to find information about requesting time off?
#
# Assistant: {'text_message': 'You can find information about requesting time off in the employee handbook or on the internal HR portal. If you need further assistance, you can also contact your HR representative directly.'}
#
# Score: 0.7 : Last Turn Score:
# The assistant's response is relevant to the user's query about finding information on requesting time off. It provides a specific direction to check the employee handbook and HR portal, or to contact HR, which is helpful and direct.
#
# Full Chat Score:
# The conversation is brief but the assistant has successfully guided the user to the resources where they can find information about requesting time off. While the assistant's response is clear and helpful, it could have included more detailed guidance on the actual process for requesting time off, which would have further improved completeness.
#
# Turn 2
#
# User: Thanks! How do I request vacation days in the internal HR portal?
#
# Assistant: {'text_message': 'To request vacation days in the internal HR portal, follow these steps:\n\n1. Log in to the HR portal with your employee credentials.\n2. Navigate to the "Time Off" or "Leave Requests" section.\n3. Select "Request Time Off" or a similar option.\n4. Fill in the required details, such as the dates and type of leave.\n5. Submit your request for approval.\n\nMake sure to check for any specific guidelines or policies related to vacation requests.'}
#
# Score: 0.9 : Last Turn Score:
# The assistant’s most recent response was highly relevant and helpful to the user's question about requesting vacation days in the HR portal. The assistant provided clear, step-by-step instructions without any ambiguity.
#
# Full Chat Score:
# Throughout the entire conversation, the assistant's responses were directly related to the user's inquiries and consistently provided the required information in a comprehensive and understandable manner. The assistant addressed both the initial request to find information and provided detailed instructions for requesting vacation days. This completeness and clarity ensured the user’s objective was fully met.
# ✅ Report saved at: /Users/denizdalkilic/Documents/Forks/PyRIT/tests/E2E/reports/CustomerAutomation/report_20250326_140921.html
