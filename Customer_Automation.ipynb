# %%
import logging
import asyncio
from pathlib import Path
import time
import datetime

# Pyrit library imports for orchestrating AH Assistant tests
from pyrit.common import IN_MEMORY, initialize_pyrit
from pyrit.prompt_target import OpenAIChatTarget, HTTPTarget
from pyrit.score.evaluator import Evaluator
from pyrit.orchestrator import AHAssistantOrchestrator
from pyrit.orchestrator.multi_turn.red_teaming_orchestrator import RTOSystemPromptPaths
from pyrit.common.text_helper import save_html_report, generate_multi_turn_html_report
from pyrit.prompt_target.http_target.parsers.AHAssistantResponseParser import AHAssistantResponseParser

# Set logging level to WARNING to reduce log output
logging.basicConfig(level=logging.WARNING)

# ------------------------------------------------------------------------------
# Setup: Define Member ID, URL, and HTTP Request Template
# ------------------------------------------------------------------------------

url=""
token""

# Define a raw HTTP POST request template with headers and a placeholder for the prompt.
start_chat_request_raw = f"""
    POST {url}
    Content-Type: application/json
    X-Authorization: {token}
    Accept: text/event-stream
    x-test-mode: true

    {{
        "data": "{{PROMPT}}"
    }}
"""

# ------------------------------------------------------------------------------
# Configuration: Strategy, Scorer, and Report Paths
# ------------------------------------------------------------------------------

# The system prompt strategy for AH Assistant testing
strategy_path = RTOSystemPromptPaths.AH_ASSISTANT_CUSTOMER.value

# YAML configuration for the evaluator (scorer)
scorer_path = "assets/AH_Evaluators/chat_evaluator.yaml"

# Directory path to save the HTML report
report_path = "tests/E2E/reports/CustomerAutomation"

# ------------------------------------------------------------------------------
# Define Objectives for Customer Automation Testing
# ------------------------------------------------------------------------------

objectives = [
    # General Recipe Requests
    "As a home cook, I want a quick and easy pasta recipe for a busy weeknight. I live gluten free and I have a nut allergy. I like meat"
]

# ------------------------------------------------------------------------------
# Main Asynchronous Routine for Running Tests and Generating Report
# ------------------------------------------------------------------------------

async def main():
    # List to store conversation reports for each objective
    results = []
    
    # Process each objective individually
    for objective in objectives:
        # Initialize Pyrit with an in-memory database to ensure a clean environment
        initialize_pyrit(memory_db_type=IN_MEMORY)
        
        # Prepare evaluator variables using the current objective
        scorer_variables = {"objective": objective}
        
        # Create a chat target for adversarial conversation using OpenAI Chat API
        chat_target = OpenAIChatTarget()
        
        # Create an HTTP target to send the prompt to the assistant service
        http_prompt_target = HTTPTarget(
            http_request=start_chat_request_raw,
            prompt_regex_string="{PROMPT}",
            timeout=60.0,
            callback_function=AHAssistantResponseParser.parse_response
        )
        
        # Create an evaluator (scorer) to assess the quality of responses,
        # using a float scale for scoring.
        chat_scorer = Evaluator(
            chat_target=OpenAIChatTarget(),
            evaluator_yaml_path=Path(scorer_path),
            additional_evaluator_variables=scorer_variables,
            scorer_type="float_scale"
        )
        
        # Set up the orchestrator for AH Assistant testing with the following parameters:
        # - adversarial_chat: the chat target for generating responses
        # - adversarial_chat_system_prompt_path: the system prompt guiding the assistant
        # - objective_target: the HTTP target to send requests to the assistant
        # - objective_scorer: the evaluator that assesses responses
        # - evaluate_chat: enables evaluation of the conversation
        # - max_turns: maximum number of conversation turns allowed
        # - use_score_as_feedback: uses scoring as feedback for conversation generation
        orchestrator = AHAssistantOrchestrator(
            adversarial_chat=chat_target,
            adversarial_chat_system_prompt_path=strategy_path,
            objective_target=http_prompt_target,
            objective_scorer=chat_scorer,
            verbose=True,
            evaluate_chat=True,
            max_turns=10,
            use_score_as_feedback=True 
        )

        # Start the timer before sending prompts.
        start_time = time.time()
        
        # Run the orchestrator attack asynchronously for the current objective
        result = await orchestrator.run_attack_async(objective=objective)

        # Calculate the total execution time.
        execution_time = time.time() - start_time

        # Retrieve and store the conversation report from the result
        results.append(await result.get_conversation_report_async())

    # ------------------------------------------------------------------------------
    # Report Generation: Save the Conversation Results as an HTML Report
    # ------------------------------------------------------------------------------
    
    # Resolve the absolute path of the report directory and create it if it doesn't exist
    report_dir = Path(report_path).resolve()
    report_dir.mkdir(parents=True, exist_ok=True)
    
    # Generate and save the HTML report using the accumulated results
    save_html_report(
        results=results,
        is_chat_evaluation=True,
        report_generator=generate_multi_turn_html_report,
        directory=str(report_dir),
        description="This report provides an overview of multi-turn customer simulations, highlighting how the assistant engages in realistic, task-focused conversations. Each dialogue is evaluated for accuracy, helpfulness, and the ability to fulfill customer objectives across multiple turns. The report includes conversation transcripts, assistant responses, and corresponding scores reflecting the quality and relevance of the interaction.",
        execution_time=execution_time
    )

# ------------------------------------------------------------------------------
# Entry Point: Run the Main Asynchronous Function
# ------------------------------------------------------------------------------


await main()
# Out:
# Starting new chat...
#
# User: Ik ben op zoek naar iets lekkers om snel te maken na werk. Heb jij suggesties voor een makkelijke, voedzame maaltijd?
#
# Assistant: {'text_message': 'Hallo! Ik kan je helpen met het vinden van een makkelijke en voedzame maaltijd. Denk aan gerechten zoals een snelle roerbakschotel met groenten en kip, een quinoa-salade met feta en groenten, of een omelet met spinazie en tomaat. Wil je dat ik specifieke recepten voor je zoek?', 'suggestion_pills': {'chips': ['Snelle roerbakschotel', 'Quinoa-salade met feta', 'Omelet met spinazie', 'Makkelijke pastarecepten']}}
#
# Extracted Thread ID:  thread_dcAcnm9nScv3RkOjNTaKD6sd
# Score: 0.3 : Last Turn Score:
# The assistant provided several suggestions for quick and easy meals, which is relevant to the user's request. However, the user asked specifically for a pasta recipe, which was included as one of the suggestion chips, but not directly addressed in the text message.
#
# Full Chat Score:
# The assistant offers several meal suggestions, however, only indirectly mentions pasta recipes in suggestion chips without addressing the user's dietary restrictions (gluten-free and nut allergy). The assistant did not fully consider the user's preference for meat and dietary needs which are crucial for achieving the user's objective. Additionally, the conversation lacks clarity and completeness in providing specific instructions.
#
# Continuing chat with thread ID: thread_dcAcnm9nScv3RkOjNTaKD6sd
#
# User: Hmm, ken je een gerecht dat snel klaar is en zonder gluten?
#
# Assistant: {'data_message': '{"type":"RECIPE_LANE","data":{"title":null,"items":[{"id":487648,"title":"Snelle runderstoof met rijst en boontjes","time":{"cook":15,"oven":0,"wait":0}', 'suggestion_pills': {'chips': ['Glutenvrije roerbakschotel', 'Snelle quinoa-salade', 'Omelet met groenten', 'Glutenvrije pasta recepten']}}
#
# Score: 0.6 : Last Turn Score:
# The last assistant response provides a recipe suggestion that is relevant to the user's request for a gluten-free dish. However, it lacks specificity and titles within the data structure, making it harder for the user to grasp the provided information efficiently.
#
# Full Chat Score:
# Throughout the conversation, the assistant has given several suggestions that cater to the user's request for quick and easy meals, including gluten-free options. The assistant consistently offers guidance via gluten-free suggestions and meal types suitable for busy weeknights. Still, the clarity and completeness of the recipe can be improved to ensure the user can follow through seamlessly. While fulfilling the objective moderately, there is room for better clarity and completeness in the assistant's responses.
#
# Continuing chat with thread ID: thread_dcAcnm9nScv3RkOjNTaKD6sd
#
# User: Heb je ook een glutenvrije pastavariant die snel te maken is en geen noten bevat?
#
# Assistant: {}
#
# Score: 0.3 : Last Turn Score:
# The assistant did not provide a response to the user's specific request for a quick, gluten-free and nut-free pasta variant. This missed opportunity resulted in a lack of immediate guidance and relevance.
#
# Full Chat Score:
# While the assistant provided some relevant suggestions initially, including options for gluten-free meals, it ultimately failed to fulfill the objective of providing a specific quick and easy gluten-free and nut-free pasta recipe. The conversation lacked clarity in the final response and completeness in achieving the user's goals.
#
# Continuing chat with thread ID: thread_dcAcnm9nScv3RkOjNTaKD6sd
#
# User: Wat vind je van glutenvrije pasta met tomatensaus en kip? Het is snel, bevat geen noten, en heeft vlees.
#
# Assistant: {'text_message': 'Glutenvrije pasta met tomatensaus en kip klinkt heerlijk en is een geweldige keuze voor een snelle maaltijd! Je kunt het eenvoudig maken door de pasta te koken en ondertussen de kip te bakken met tomatensaus. Heb je specifieke ingrediënten of een recept nodig voor dit gerecht?', 'suggestion_pills': {'chips': ['Recept voor glutenvrije pasta', 'Tomatensaus maken', 'Hoe kip bakken?', 'Glutenvrije pasta kopen']}}
#
# Score: 0.6 : Last Turn Score: The assistant affirmed the user's suggestion of 'glutenvrije pasta met tomatensaus en kip,' which is a relevant and supportive response. The assistant also asked if the user needed specific ingredients or a recipe, which is helpful.
#
# Full Chat Score: Throughout the conversation, the assistant provided useful suggestions for meals, asked clarifying questions, and ultimately supported the user's exact request for a quick and easy pasta recipe. The repeated suggestions of recipes and meal ideas indicate completeness, and instructions were clear. However, one user prompt did not receive a response (‘Heb je ook een glutenvrije pastavariant die snel te maken is en geen noten bevat?’), which affects the overall coherence and completeness evaluation.
#
# Continuing chat with thread ID: thread_dcAcnm9nScv3RkOjNTaKD6sd
#
# User: Welke specifieke ingrediënten heb je nodig voor de glutenvrije pasta met tomatensaus en kip? Heb je bijvoorbeeld een voorkeur voor een bepaalde soort tomatensaus?
#
# Assistant: {'text_message': 'Voor glutenvrije pasta met tomatensaus en kip heb je de volgende ingrediënten nodig:- Glutenvrije pasta (bijvoorbeeld penne of spaghetti)- Kipfilet (in blokjes of reepjes)- Tomatensaus (je kunt kiezen voor een simpele passata of een gekruide tomatensaus)- Uien (fijngehakt)- Knoflook (fijngehakt)- Olijfolie- Zout en peper- Eventueel verse basilicum of oregano voor extra smaakJe kunt een kant-en-klare tomatensaus gebruiken of zelf een saus maken met tomaten, uien en kruiden. Heb je hulp nodig bij het bereiden van dit gerecht?', 'suggestion_pills': {'chips': ['Zelf tomatensaus maken', 'Kant-en-klare tomatensaus opties', 'Hoe kipfilet bereiden?', 'Glutenvrije pasta merken']}}
#
# Score: 0.8 : Last Turn Score:
# The assistant provided clear and detailed information on the ingredients needed for the gluten-free pasta with tomato sauce and chicken recipe. This response directly addresses the user's request for specific ingredients. No major issues are present in this turn.
#
# Full Chat Score:
# The assistant's responses throughout the conversation were relevant and directed towards finding a quick and easy gluten-free, nut-free pasta recipe with meat, which aligns with the user's objective. The assistant presented multiple options and provided detailed information for the selected dish. However, there was a lapse regarding the user's request for gluten-free pasta in the third exchange, which could temporarily hinder the user. Despite this, the assistant ultimately helped the user achieve the goal effectively.
#
# Continuing chat with thread ID: thread_dcAcnm9nScv3RkOjNTaKD6sd
#
# User: Klinkt goed! Heb je een voorkeur voor een kant-en-klare tomatensaus, of wil je hem zelf maken?
#
# Assistant: {'text_message': 'Het hangt af van je voorkeur en tijd! Een kant-en-klare tomatensaus is snel en handig, vooral als je weinig tijd hebt. Aan de andere kant, zelf een saus maken geeft je meer controle over de smaken en ingrediënten. Als je het zelf wilt maken, kun je verse tomaten, uien, knoflook en kruiden gebruiken voor een heerlijke, verse smaak. Wat heb je liever?', 'suggestion_pills': {'chips': ['Kant-en-klare tomatensaus opties', 'Zelfgemaakte tomatensaus recept', 'Hoe maak je tomatensaus?', 'Verse tomaten bewaren']}}
#
# Score: 0.8 : Last Turn Score:
# In the last conversation, the user asked whether they should use a store-bought or homemade tomato sauce. The assistant’s response was relevant, suggesting both options and mentioning the benefits of each. It included helpful follow-up suggestions, addressing the user's question directly and completely.
#
# Full Chat Score:
# Throughout the conversation, the assistant was attentive and responsive to the user's dietary restrictions (gluten-free and nut allergy) and preference for meat. The assistant provided suitable recipes and detailed ingredient lists, assisting the user in achieving their objective of finding a quick and easy pasta recipe for a busy weeknight meal. The chat included clear instructions and suggestions, maintaining clarity and completeness. Therefore, the assistant effectively helped the user achieve their goal, resulting in a high score.
#
# Continuing chat with thread ID: thread_dcAcnm9nScv3RkOjNTaKD6sd
#
# User: Heb je liever een kant-en-klare tomatensaus? Dat gaat veel sneller!
#
# Assistant: {'data_message': '{"type":"PRODUCT_LANE","data":{"title":null,"items":[{"id":96755,"title":"Carbonara pastasaus","brand":"AH","salesUnitSize":"225 g","images":[{"rendition":"LARGE","url":"https://static.ah.nl/dam/product/AHI_4354523130303932303934?revLabel=1&rendition=800x800_JPG_Q90&fileType=binary","width":800,"height":800}', 'suggestion_pills': {'chips': ['Kant-en-klare tomatensaus opties', 'Zelf tomatensaus maken', 'Tomatensaus recepten', 'Hoe tomatensaus bewaren?']}}
#
# Score: 0.8 : Last Turn Score: The assistant responded thoughtfully by offering the user a product suggestion for a quick pasta sauce, but the product offered was not a tomato sauce, which was specifically requested. Despite this, it provided useful information about a convenient option, which keeps it quite relevant.
#
# Full Chat Score: Overall, the assistant provided a variety of meaningful suggestions and recipes to help the user find a suitable, gluten-free, nut-free pasta dish with meat for a busy weeknight. Instructions were clear and multiple options were provided throughout the conversation. Completing the exchange with offering specific ingredient and product suggestions followed through with the user's objective effectively.
#
# Continuing chat with thread ID: thread_dcAcnm9nScv3RkOjNTaKD6sd
#
# User: Deze optie is prima, maar wel carbonara. Heb je een kant-en-klare tomatensaus zonder gluten en zonder noten?
#
# Assistant: {'data_message': '{"type":"PRODUCT_LANE","data":{"title":null,"items":[{"id":38062,"title":"Saus voor macaroni tomaat/groente","brand":null,"salesUnitSize":"420 g","images":[]}', 'suggestion_pills': {'chips': ['Glutenvrije tomatensaus opties', 'Recepten met tomatensaus', 'Tomatensaus zelf maken']}}
#
# Score: 0.8 : Last Turn Score:
# The assistant's last response gives the user an option for a quick meal—'Saus voor macaroni tomaat/groente' which fits the user’s criteria of no gluten and no nuts. This is helpful and relevant, scoring well on this aspect.
#
# Full Chat Score:
# Overall, the assistant provided a clear and relevant conversation that aligns with the user's objective. The assistant offers several suitable meal options fitting the criteria of no gluten and no nuts, such as gluten-free pasta with tomato sauce and chicken. The assistant's clarity is good, providing specific ingredients and suggestions about ready-made versus homemade sauces. Completeness was slightly lacking during the conversation where the assistant did not always provide immediate details for some user queries. However, these were quickly addressed in subsequent responses, contributing positively towards fulfilling the user's objective.
#
# Continuing chat with thread ID: thread_dcAcnm9nScv3RkOjNTaKD6sd
#
# User: Deze glutenvrije tomatensaus zonder noten lijkt ideaal! Wil je deze gebruiken voor je pasta met kip?
#
# Assistant: {'text_message': 'Ja, die glutenvrije tomatensaus zonder noten is een uitstekende keuze voor je pasta met kip! Je kunt de saus eenvoudig verwarmen en mengen met de gekookte pasta en kip. Heb je nog andere vragen of heb je hulp nodig bij het bereiden van het gerecht?', 'suggestion_pills': {'chips': ['Recepten met kip', 'Hoe kipfilet bereiden?', 'Glutenvrije pastarecepten', 'Tomatensaus bewaren']}}
#
# Score: 0.8 : Last Turn Score:
# The assistant provided a clear and relevant response confirming that the suggested gluten-free tomato sauce without nuts is an excellent choice for the user's pasta with chicken meal. Additionally, the assistant offered further assistance if needed.
#
# Full Chat Score:
# The entire conversation between the user and the assistant was largely focused on meeting the user's dietary restrictions and preferences. The assistant responded with suitable meal options, paid attention to the user's gluten-free and nut-free requirements, and addressed all questions regarding ingredients and preparation. The assistant ensured clarity in the instructions given and provided relevant suggestion chips to further assist the user. Overall, the assistant fulfilled the objective of finding a quick and easy gluten-free pasta recipe tailored to the user's needs and preferences.
#
# Continuing chat with thread ID: thread_dcAcnm9nScv3RkOjNTaKD6sd
#
# User: Dank je! Ik ga hiermee aan de slag. Als ik vragen heb, laat ik het weten.
#
# Assistant: {'text_message': 'Graag gedaan! Veel plezier met koken! Als je nog vragen hebt, aarzel dan niet om het te vragen. Eet smakelijk!', 'suggestion_pills': {'chips': ['Meer kip recepten', 'Hoe kipfilet bakken?', 'Verse kruiden voor kip', 'Hoe kip bewaren?']}}
#
# Score: 0.9 : Last Turn Score: The assistant successfully responded to the user's affirmation about using the selected tomato sauce for the pasta with chicken. It acknowledged the user's choice and confirmed the suitability of the ingredient, ensuring the user was set to proceed with cooking.
#
# Full Chat Score: The assistant provided clear, detailed, and relevant information throughout the conversation. Each response addressed the user's needs and dietary restrictions, offering specific recipes and ingredient suggestions. The assistant also provided options for both store-bought and homemade tomato sauce and reviewed the necessary ingredients thoroughly. The instructions were complete and tailored to the user's preferences for a quick and easy gluten-free pasta meal that contains meat and avoids nuts. This comprehensiveness and relevance in meeting the user's objective warrant a high score for the chat.
# Report saved at: /Users/denizdalkilic/Documents/Forks/PyRIT/tests/E2E/reports/CustomerAutomation/report_20250311_111757.html
